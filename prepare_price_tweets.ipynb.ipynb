# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
caminho = '/content/Dados/tweets_keywords_relations_agg_by_day.csv'
acoes_petr4 = '/content/Dados/Petrobras PETR4 - Histórico  InfoMoney.csv'
acoes_vale3 = '/content/Dados/Vale S.A. VALE3 - Histórico  InfoMoney.csv'

df = pd.read_csv(caminho)
stock_petr = pd.read_csv(acoes_petr4, thousands=',')
stock_vale = pd.read_csv(acoes_vale3, thousands=',')

# %% [markdown]
# # Petr4

# %%
df_petr4 = df.query('stock == "PETR4"')

# %%
df_petr4
# Out:
#      stock  valorização_mean  valorização_median  valorização_q1  \
# 0    PETR4          0.501828            0.501828        0.253213
# 1    PETR4          0.501828            0.501828        0.253213
# 2    PETR4          0.501828            0.501828        0.253213
# 3    PETR4          0.501828            0.501828        0.253213
# 4    PETR4          0.501828            0.501828        0.253213
# ..     ...               ...                 ...             ...
# 726  PETR4          0.536770            0.565749        0.308531
# 727  PETR4          0.449981            0.393969        0.076732
# 728  PETR4          0.612887            0.798810        0.308213
# 729  PETR4          0.989611            0.989611        0.989611
# 730  PETR4          0.589883            0.724805        0.209526
#
#      valorização_q3  valorização_count  bom negócio_mean  bom negócio_median  \
# 0          0.750443                  2          0.491784            0.491784
# 1          0.750443                  2          0.491784            0.491784
# 2          0.750443                  2          0.491784            0.491784
# 3          0.750443                  2          0.491784            0.491784
# 4          0.750443                  2          0.491784            0.491784
# ..              ...                ...               ...                 ...
# 726        0.825538                 10          0.555506            0.534227
# 727        0.845444                 22          0.468577            0.530161
# 728        0.939821                  5          0.579131            0.540118
# 729        0.989611                  1          0.876924            0.876924
# 730        0.956659                 22          0.580172            0.575521
#
#      bom negócio_q1  bom negócio_q3  ...  prejuízo_q1  prejuízo_q3  \
# 0          0.367215        0.616352  ...     0.077469     0.121519
# 1          0.367215        0.616352  ...     0.077469     0.121519
# 2          0.367215        0.616352  ...     0.077469     0.121519
# 3          0.367215        0.616352  ...     0.077469     0.121519
# 4          0.367215        0.616352  ...     0.077469     0.121519
# ..              ...             ...  ...          ...          ...
# 726        0.389310        0.793810  ...     0.005745     0.457689
# 727        0.225760        0.681434  ...     0.029861     0.695087
# 728        0.435450        0.934173  ...     0.002879     0.083165
# 729        0.876924        0.876924  ...     0.002545     0.002545
# 730        0.478601        0.756689  ...     0.004744     0.326127
#
#      prejuízo_count  governo_mean  governo_median  governo_q1  governo_q3  \
# 0                 2      0.887368        0.887368    0.886389    0.888347
# 1                 2      0.887368        0.887368    0.886389    0.888347
# 2                 2      0.887368        0.887368    0.886389    0.888347
# 3                 2      0.887368        0.887368    0.886389    0.888347
# 4                 2      0.887368        0.887368    0.886389    0.888347
# ..              ...           ...             ...         ...         ...
# 726              10      0.458097        0.416679    0.068321    0.866780
# 727              22      0.319317        0.193473    0.014151    0.572948
# 728               5      0.070922        0.048216    0.038298    0.128600
# 729               1      0.011657        0.011657    0.011657    0.011657
# 730              22      0.260544        0.112991    0.019496    0.463646
#
#      governo_count  has_tweets    datetime
# 0                2           0  2022-06-01
# 1                2           0  2022-06-02
# 2                2           0  2022-06-03
# 3                2           0  2022-06-04
# 4                2           0  2022-06-05
# ..             ...         ...         ...
# 726             10           1  2024-05-27
# 727             22           1  2024-05-28
# 728              5           1  2024-05-29
# 729              1           1  2024-05-30
# 730             22           1  2024-05-31
#
# [731 rows x 43 columns]

# %%
df_petr4['datetime'] = df_petr4['datetime'].astype('datetime64[ns]')
# Out:
# <ipython-input-82-2a37c27708de>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_petr4['datetime'] = df_petr4['datetime'].astype('datetime64[ns]')

# %%
stock_petr['datetime'] = pd.to_datetime(stock_petr['DATA'])
stock_petr
# Out:
# <ipython-input-83-e612cee7b329>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   stock_petr['datetime'] = pd.to_datetime(stock_petr['DATA'])
#            DATA  ABERTURA  FECHAMENTO  VARIAÇÃO  MÍNIMO  MÁXIMO   VOLUME  \
# 0    31/05/2024      3697        3781       276    3694    3791    2,02B
# 1    29/05/2024      3676        3680       -13    3650    3696    1,07B
# 2    28/05/2024      3650        3685       213    3647    3732    1,71B
# 3    27/05/2024      3579        3608       109    3576    3614  485,14M
# 4    24/05/2024      3613        3569       -54    3565    3625  844,46M
# ..          ...       ...         ...       ...     ...     ...      ...
# 494  07/06/2022      1539        1563       119    1537    1595    1,26B
# 495  06/06/2022      1555        1544         7    1524    1556  600,11M
# 496  03/06/2022      1514        1543       175    1505    1551  919,79M
# 497  02/06/2022      1528        1517       -87    1506    1532  763,30M
# 498  01/06/2022      1524        1530       -13    1521    1546  704,59M
#
#       datetime
# 0   2024-05-31
# 1   2024-05-29
# 2   2024-05-28
# 3   2024-05-27
# 4   2024-05-24
# ..         ...
# 494 2022-06-07
# 495 2022-06-06
# 496 2022-06-03
# 497 2022-06-02
# 498 2022-06-01
#
# [499 rows x 8 columns]

# %%
petr4 = pd.merge(stock_petr, df_petr4, how="inner", on="datetime")
petr4
# Out:
#            DATA  ABERTURA  FECHAMENTO  VARIAÇÃO  MÍNIMO  MÁXIMO   VOLUME  \
# 0    31/05/2024      3697        3781       276    3694    3791    2,02B
# 1    29/05/2024      3676        3680       -13    3650    3696    1,07B
# 2    28/05/2024      3650        3685       213    3647    3732    1,71B
# 3    27/05/2024      3579        3608       109    3576    3614  485,14M
# 4    24/05/2024      3613        3569       -54    3565    3625  844,46M
# ..          ...       ...         ...       ...     ...     ...      ...
# 494  07/06/2022      1539        1563       119    1537    1595    1,26B
# 495  06/06/2022      1555        1544         7    1524    1556  600,11M
# 496  03/06/2022      1514        1543       175    1505    1551  919,79M
# 497  02/06/2022      1528        1517       -87    1506    1532  763,30M
# 498  01/06/2022      1524        1530       -13    1521    1546  704,59M
#
#       datetime  stock  valorização_mean  ...  prejuízo_median  prejuízo_q1  \
# 0   2024-05-31  PETR4          0.589883  ...         0.044422     0.004744
# 1   2024-05-29  PETR4          0.612887  ...         0.005163     0.002879
# 2   2024-05-28  PETR4          0.449981  ...         0.220025     0.029861
# 3   2024-05-27  PETR4          0.536770  ...         0.150303     0.005745
# 4   2024-05-24  PETR4          0.497588  ...         0.126575     0.040182
# ..         ...    ...               ...  ...              ...          ...
# 494 2022-06-07  PETR4          0.501828  ...         0.099494     0.077469
# 495 2022-06-06  PETR4          0.501828  ...         0.099494     0.077469
# 496 2022-06-03  PETR4          0.501828  ...         0.099494     0.077469
# 497 2022-06-02  PETR4          0.501828  ...         0.099494     0.077469
# 498 2022-06-01  PETR4          0.501828  ...         0.099494     0.077469
#
#      prejuízo_q3  prejuízo_count  governo_mean  governo_median  governo_q1  \
# 0       0.326127              22      0.260544        0.112991    0.019496
# 1       0.083165               5      0.070922        0.048216    0.038298
# 2       0.695087              22      0.319317        0.193473    0.014151
# 3       0.457689              10      0.458097        0.416679    0.068321
# 4       0.717424               9      0.457392        0.264063    0.205857
# ..           ...             ...           ...             ...         ...
# 494     0.121519               2      0.887368        0.887368    0.886389
# 495     0.121519               2      0.887368        0.887368    0.886389
# 496     0.121519               2      0.887368        0.887368    0.886389
# 497     0.121519               2      0.887368        0.887368    0.886389
# 498     0.121519               2      0.887368        0.887368    0.886389
#
#      governo_q3  governo_count  has_tweets
# 0      0.463646             22           1
# 1      0.128600              5           1
# 2      0.572948             22           1
# 3      0.866780             10           1
# 4      0.881397              9           1
# ..          ...            ...         ...
# 494    0.888347              2           0
# 495    0.888347              2           0
# 496    0.888347              2           0
# 497    0.888347              2           0
# 498    0.888347              2           0
#
# [499 rows x 50 columns]

# %%
petr4_final = petr4.drop(columns=['DATA', 'ABERTURA', 'FECHAMENTO', 'MÍNIMO', 'MÁXIMO','VOLUME', 'stock'])
cols = list(petr4_final)
cols.insert(0, cols.pop(cols.index('datetime')))
petr4_final = petr4_final.loc[:, cols]

# %% [markdown]
# ## DataFrame Final

# %%
petr4_final
# Out:
#       datetime  VARIAÇÃO  valorização_mean  valorização_median  \
# 0   2024-05-31       276          0.589883            0.724805
# 1   2024-05-29       -13          0.612887            0.798810
# 2   2024-05-28       213          0.449981            0.393969
# 3   2024-05-27       109          0.536770            0.565749
# 4   2024-05-24       -54          0.497588            0.438173
# ..         ...       ...               ...                 ...
# 494 2022-06-07       119          0.501828            0.501828
# 495 2022-06-06         7          0.501828            0.501828
# 496 2022-06-03       175          0.501828            0.501828
# 497 2022-06-02       -87          0.501828            0.501828
# 498 2022-06-01       -13          0.501828            0.501828
#
#      valorização_q1  valorização_q3  valorização_count  bom negócio_mean  \
# 0          0.209526        0.956659                 22          0.580172
# 1          0.308213        0.939821                  5          0.579131
# 2          0.076732        0.845444                 22          0.468577
# 3          0.308531        0.825538                 10          0.555506
# 4          0.256983        0.770160                  9          0.628261
# ..              ...             ...                ...               ...
# 494        0.253213        0.750443                  2          0.491784
# 495        0.253213        0.750443                  2          0.491784
# 496        0.253213        0.750443                  2          0.491784
# 497        0.253213        0.750443                  2          0.491784
# 498        0.253213        0.750443                  2          0.491784
#
#      bom negócio_median  bom negócio_q1  ...  prejuízo_median  prejuízo_q1  \
# 0              0.575521        0.478601  ...         0.044422     0.004744
# 1              0.540118        0.435450  ...         0.005163     0.002879
# 2              0.530161        0.225760  ...         0.220025     0.029861
# 3              0.534227        0.389310  ...         0.150303     0.005745
# 4              0.685696        0.327318  ...         0.126575     0.040182
# ..                  ...             ...  ...              ...          ...
# 494            0.491784        0.367215  ...         0.099494     0.077469
# 495            0.491784        0.367215  ...         0.099494     0.077469
# 496            0.491784        0.367215  ...         0.099494     0.077469
# 497            0.491784        0.367215  ...         0.099494     0.077469
# 498            0.491784        0.367215  ...         0.099494     0.077469
#
#      prejuízo_q3  prejuízo_count  governo_mean  governo_median  governo_q1  \
# 0       0.326127              22      0.260544        0.112991    0.019496
# 1       0.083165               5      0.070922        0.048216    0.038298
# 2       0.695087              22      0.319317        0.193473    0.014151
# 3       0.457689              10      0.458097        0.416679    0.068321
# 4       0.717424               9      0.457392        0.264063    0.205857
# ..           ...             ...           ...             ...         ...
# 494     0.121519               2      0.887368        0.887368    0.886389
# 495     0.121519               2      0.887368        0.887368    0.886389
# 496     0.121519               2      0.887368        0.887368    0.886389
# 497     0.121519               2      0.887368        0.887368    0.886389
# 498     0.121519               2      0.887368        0.887368    0.886389
#
#      governo_q3  governo_count  has_tweets
# 0      0.463646             22           1
# 1      0.128600              5           1
# 2      0.572948             22           1
# 3      0.866780             10           1
# 4      0.881397              9           1
# ..          ...            ...         ...
# 494    0.888347              2           0
# 495    0.888347              2           0
# 496    0.888347              2           0
# 497    0.888347              2           0
# 498    0.888347              2           0
#
# [499 rows x 43 columns]

# %% [markdown]
# # VALE3

# %%
df_vale3 = df.query('stock == "VALE3"')
df_vale3
# Out:
#       stock  valorização_mean  valorização_median  valorização_q1  \
# 731   VALE3          0.993576            0.994342        0.992913
# 732   VALE3          0.827985            0.827985        0.827985
# 733   VALE3          0.738488            0.726043        0.625784
# 734   VALE3          0.738488            0.726043        0.625784
# 735   VALE3          0.738488            0.726043        0.625784
# ...     ...               ...                 ...             ...
# 1457  VALE3          0.588541            0.748972        0.411575
# 1458  VALE3          0.702186            0.724803        0.562714
# 1459  VALE3          0.532552            0.532929        0.071492
# 1460  VALE3          0.999218            0.999218        0.999218
# 1461  VALE3          0.561724            0.438410        0.404629
#
#       valorização_q3  valorização_count  bom negócio_mean  bom negócio_median  \
# 731         0.994622                  3          0.732445            0.668000
# 732         0.827985                  1          0.846314            0.846314
# 733         0.844969                  3          0.884189            0.894976
# 734         0.844969                  3          0.884189            0.894976
# 735         0.844969                  3          0.884189            0.894976
# ...              ...                ...               ...                 ...
# 1457        0.812859                  5          0.553513            0.663868
# 1458        0.864276                  4          0.737152            0.702927
# 1459        0.993988                  4          0.641740            0.769118
# 1460        0.999218                  1          0.884908            0.884908
# 1461        0.595506                  4          0.787209            0.731088
#
#       bom negócio_q1  bom negócio_q3  ...  prejuízo_q1  prejuízo_q3  \
# 731         0.637375        0.795293  ...     0.025736     0.418133
# 732         0.846314        0.846314  ...     0.012965     0.012965
# 733         0.866198        0.907574  ...     0.000727     0.083457
# 734         0.866198        0.907574  ...     0.000727     0.083457
# 735         0.866198        0.907574  ...     0.000727     0.083457
# ...              ...             ...  ...          ...          ...
# 1457        0.639569        0.689314  ...     0.013599     0.039807
# 1458        0.636298        0.803780  ...     0.028030     0.841715
# 1459        0.572464        0.838395  ...     0.252097     0.918396
# 1460        0.884908        0.884908  ...     0.278165     0.278165
# 1461        0.706536        0.811761  ...     0.004124     0.031219
#
#       prejuízo_count  governo_mean  governo_median  governo_q1  governo_q3  \
# 731                3      0.622705        0.678281    0.479734    0.793464
# 732                1      0.135096        0.135096    0.135096    0.135096
# 733                3      0.062783        0.020353    0.011103    0.093248
# 734                3      0.062783        0.020353    0.011103    0.093248
# 735                3      0.062783        0.020353    0.011103    0.093248
# ...              ...           ...             ...         ...         ...
# 1457               5      0.456577        0.528233    0.402417    0.644755
# 1458               4      0.280694        0.079572    0.017608    0.342658
# 1459               4      0.681841        0.755330    0.474074    0.963098
# 1460               1      0.560456        0.560456    0.560456    0.560456
# 1461               4      0.033226        0.002362    0.001891    0.033696
#
#       governo_count  has_tweets    datetime
# 731               3           1  2022-06-01
# 732               1           1  2022-06-02
# 733               3           1  2022-06-03
# 734               3           0  2022-06-04
# 735               3           0  2022-06-05
# ...             ...         ...         ...
# 1457              5           1  2024-05-27
# 1458              4           1  2024-05-28
# 1459              4           1  2024-05-29
# 1460              1           1  2024-05-30
# 1461              4           1  2024-05-31
#
# [731 rows x 43 columns]

# %%
stock_vale
# Out:
#            DATA  ABERTURA  FECHAMENTO  VARIAÇÃO  MÍNIMO  MÁXIMO   VOLUME
# 0    31/05/2024      6289        6320        -6    6279    6345    1,48B
# 1    29/05/2024      6344        6324      -102    6297    6373    1,04B
# 2    28/05/2024      6528        6389      -216    6335    6529    1,42B
# 3    27/05/2024      6491        6530        34    6471    6530  330,38M
# 4    24/05/2024      6500        6508         5    6490    6566  763,37M
# ..          ...       ...         ...       ...     ...     ...      ...
# 494  07/06/2022      7445        7646       234    7435    7669    2,05B
# 495  06/06/2022      7564        7472        10    7472    7576    1,11B
# 496  03/06/2022      7552        7464      -160    7456    7579    1,38B
# 497  02/06/2022      7594        7586       188    7510    7618    1,89B
# 498  01/06/2022      7273        7445       235    7256    7491    1,90B
#
# [499 rows x 7 columns]

# %%
df_vale3['datetime'] = df_vale3['datetime'].astype('datetime64[ns]')
# Out:
# <ipython-input-89-f4c183cba2dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_vale3['datetime'] = df_vale3['datetime'].astype('datetime64[ns]')

# %%
stock_vale['datetime'] = pd.to_datetime(stock_vale['DATA'])
stock_vale
# Out:
# <ipython-input-90-36c0a1a7a9cc>:1: UserWarning: Parsing dates in %d/%m/%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   stock_vale['datetime'] = pd.to_datetime(stock_vale['DATA'])
#            DATA  ABERTURA  FECHAMENTO  VARIAÇÃO  MÍNIMO  MÁXIMO   VOLUME  \
# 0    31/05/2024      6289        6320        -6    6279    6345    1,48B
# 1    29/05/2024      6344        6324      -102    6297    6373    1,04B
# 2    28/05/2024      6528        6389      -216    6335    6529    1,42B
# 3    27/05/2024      6491        6530        34    6471    6530  330,38M
# 4    24/05/2024      6500        6508         5    6490    6566  763,37M
# ..          ...       ...         ...       ...     ...     ...      ...
# 494  07/06/2022      7445        7646       234    7435    7669    2,05B
# 495  06/06/2022      7564        7472        10    7472    7576    1,11B
# 496  03/06/2022      7552        7464      -160    7456    7579    1,38B
# 497  02/06/2022      7594        7586       188    7510    7618    1,89B
# 498  01/06/2022      7273        7445       235    7256    7491    1,90B
#
#       datetime
# 0   2024-05-31
# 1   2024-05-29
# 2   2024-05-28
# 3   2024-05-27
# 4   2024-05-24
# ..         ...
# 494 2022-06-07
# 495 2022-06-06
# 496 2022-06-03
# 497 2022-06-02
# 498 2022-06-01
#
# [499 rows x 8 columns]

# %%
vale3 = pd.merge(stock_vale, df_vale3, how="inner", on="datetime")
vale3
# Out:
#            DATA  ABERTURA  FECHAMENTO  VARIAÇÃO  MÍNIMO  MÁXIMO   VOLUME  \
# 0    31/05/2024      6289        6320        -6    6279    6345    1,48B
# 1    29/05/2024      6344        6324      -102    6297    6373    1,04B
# 2    28/05/2024      6528        6389      -216    6335    6529    1,42B
# 3    27/05/2024      6491        6530        34    6471    6530  330,38M
# 4    24/05/2024      6500        6508         5    6490    6566  763,37M
# ..          ...       ...         ...       ...     ...     ...      ...
# 494  07/06/2022      7445        7646       234    7435    7669    2,05B
# 495  06/06/2022      7564        7472        10    7472    7576    1,11B
# 496  03/06/2022      7552        7464      -160    7456    7579    1,38B
# 497  02/06/2022      7594        7586       188    7510    7618    1,89B
# 498  01/06/2022      7273        7445       235    7256    7491    1,90B
#
#       datetime  stock  valorização_mean  ...  prejuízo_median  prejuízo_q1  \
# 0   2024-05-31  VALE3          0.561724  ...         0.015974     0.004124
# 1   2024-05-29  VALE3          0.532552  ...         0.615430     0.252097
# 2   2024-05-28  VALE3          0.702186  ...         0.435718     0.028030
# 3   2024-05-27  VALE3          0.588541  ...         0.015382     0.013599
# 4   2024-05-24  VALE3          0.572810  ...         0.004094     0.001189
# ..         ...    ...               ...  ...              ...          ...
# 494 2022-06-07  VALE3          0.733622  ...         0.036432     0.013171
# 495 2022-06-06  VALE3          0.837644  ...         0.508081     0.263358
# 496 2022-06-03  VALE3          0.738488  ...         0.001050     0.000727
# 497 2022-06-02  VALE3          0.827985  ...         0.012965     0.012965
# 498 2022-06-01  VALE3          0.993576  ...         0.042204     0.025736
#
#      prejuízo_q3  prejuízo_count  governo_mean  governo_median  governo_q1  \
# 0       0.031219               4      0.033226        0.002362    0.001891
# 1       0.918396               4      0.681841        0.755330    0.474074
# 2       0.841715               4      0.280694        0.079572    0.017608
# 3       0.039807               5      0.456577        0.528233    0.402417
# 4       0.024490              10      0.529440        0.711643    0.003774
# ..           ...             ...           ...             ...         ...
# 494     0.039361               5      0.401423        0.278783    0.262803
# 495     0.752803               2      0.443267        0.443267    0.239648
# 496     0.083457               3      0.062783        0.020353    0.011103
# 497     0.012965               1      0.135096        0.135096    0.135096
# 498     0.418133               3      0.622705        0.678281    0.479734
#
#      governo_q3  governo_count  has_tweets
# 0      0.033696              4           1
# 1      0.963098              4           1
# 2      0.342658              4           1
# 3      0.644755              5           1
# 4      0.939589             10           1
# ..          ...            ...         ...
# 494    0.425698              5           1
# 495    0.646886              2           1
# 496    0.093248              3           1
# 497    0.135096              1           1
# 498    0.793464              3           1
#
# [499 rows x 50 columns]

# %%
vale3_final = vale3.drop(columns=['DATA', 'ABERTURA', 'FECHAMENTO', 'MÍNIMO', 'MÁXIMO','VOLUME', 'stock'])
cols = list(vale3_final)
cols.insert(0, cols.pop(cols.index('datetime')))
vale3_final = vale3_final.loc[:, cols]

# %% [markdown]
# ## DataFrame Final

# %%
vale3_final
# Out:
#       datetime  VARIAÇÃO  valorização_mean  valorização_median  \
# 0   2024-05-31        -6          0.561724            0.438410
# 1   2024-05-29      -102          0.532552            0.532929
# 2   2024-05-28      -216          0.702186            0.724803
# 3   2024-05-27        34          0.588541            0.748972
# 4   2024-05-24         5          0.572810            0.483266
# ..         ...       ...               ...                 ...
# 494 2022-06-07       234          0.733622            0.865744
# 495 2022-06-06        10          0.837644            0.837644
# 496 2022-06-03      -160          0.738488            0.726043
# 497 2022-06-02       188          0.827985            0.827985
# 498 2022-06-01       235          0.993576            0.994342
#
#      valorização_q1  valorização_q3  valorização_count  bom negócio_mean  \
# 0          0.404629        0.595506                  4          0.787209
# 1          0.071492        0.993988                  4          0.641740
# 2          0.562714        0.864276                  4          0.737152
# 3          0.411575        0.812859                  5          0.553513
# 4          0.267237        0.975193                 10          0.666688
# ..              ...             ...                ...               ...
# 494        0.710052        0.996097                  5          0.420262
# 495        0.790102        0.885187                  2          0.564583
# 496        0.625784        0.844969                  3          0.884189
# 497        0.827985        0.827985                  1          0.846314
# 498        0.992913        0.994622                  3          0.732445
#
#      bom negócio_median  bom negócio_q1  ...  prejuízo_median  prejuízo_q1  \
# 0              0.731088        0.706536  ...         0.015974     0.004124
# 1              0.769118        0.572464  ...         0.615430     0.252097
# 2              0.702927        0.636298  ...         0.435718     0.028030
# 3              0.663868        0.639569  ...         0.015382     0.013599
# 4              0.678658        0.616157  ...         0.004094     0.001189
# ..                  ...             ...  ...              ...          ...
# 494            0.474970        0.119269  ...         0.036432     0.013171
# 495            0.564583        0.396314  ...         0.508081     0.263358
# 496            0.894976        0.866198  ...         0.001050     0.000727
# 497            0.846314        0.846314  ...         0.012965     0.012965
# 498            0.668000        0.637375  ...         0.042204     0.025736
#
#      prejuízo_q3  prejuízo_count  governo_mean  governo_median  governo_q1  \
# 0       0.031219               4      0.033226        0.002362    0.001891
# 1       0.918396               4      0.681841        0.755330    0.474074
# 2       0.841715               4      0.280694        0.079572    0.017608
# 3       0.039807               5      0.456577        0.528233    0.402417
# 4       0.024490              10      0.529440        0.711643    0.003774
# ..           ...             ...           ...             ...         ...
# 494     0.039361               5      0.401423        0.278783    0.262803
# 495     0.752803               2      0.443267        0.443267    0.239648
# 496     0.083457               3      0.062783        0.020353    0.011103
# 497     0.012965               1      0.135096        0.135096    0.135096
# 498     0.418133               3      0.622705        0.678281    0.479734
#
#      governo_q3  governo_count  has_tweets
# 0      0.033696              4           1
# 1      0.963098              4           1
# 2      0.342658              4           1
# 3      0.644755              5           1
# 4      0.939589             10           1
# ..          ...            ...         ...
# 494    0.425698              5           1
# 495    0.646886              2           1
# 496    0.093248              3           1
# 497    0.135096              1           1
# 498    0.793464              3           1
#
# [499 rows x 43 columns]

# %% [markdown]
# # Correlações:

# %% [markdown]
# ### PETR4

# %%
df = petr4_final.corr()
df.head()
# Out:
#                     datetime  VARIAÇÃO  valorização_mean  valorização_median  \
# datetime            1.000000  0.001475          0.062735            0.073708
# VARIAÇÃO            0.001475  1.000000          0.070452            0.058290
# valorização_mean    0.062735  0.070452          1.000000            0.941664
# valorização_median  0.073708  0.058290          0.941664            1.000000
# valorização_q1      0.109457  0.111867          0.864368            0.787607
#
#                     valorização_q1  valorização_q3  valorização_count  \
# datetime                  0.109457        0.024680          -0.133366
# VARIAÇÃO                  0.111867        0.002867          -0.134901
# valorização_mean          0.864368        0.848734          -0.023364
# valorização_median        0.787607        0.854912           0.051931
# valorização_q1            1.000000        0.499830          -0.284338
#
#                     bom negócio_mean  bom negócio_median  bom negócio_q1  ...  \
# datetime                    0.019938           -0.029469        0.014695  ...
# VARIAÇÃO                    0.085335            0.116115        0.098170  ...
# valorização_mean            0.470584            0.423987        0.443233  ...
# valorização_median          0.452732            0.423959        0.430748  ...
# valorização_q1              0.421152            0.347004        0.545089  ...
#
#                     prejuízo_median  prejuízo_q1  prejuízo_q3  prejuízo_count  \
# datetime                  -0.092081    -0.036581    -0.084724       -0.133366
# VARIAÇÃO                  -0.095672    -0.032990    -0.100943       -0.134901
# valorização_mean          -0.019938     0.027250    -0.055105       -0.023364
# valorização_median        -0.076180    -0.023395    -0.074730        0.051931
# valorização_q1             0.075733     0.210000    -0.125110       -0.284338
#
#                     governo_mean  governo_median  governo_q1  governo_q3  \
# datetime               -0.230637       -0.317535   -0.203592   -0.159014
# VARIAÇÃO               -0.028327       -0.039059   -0.010600   -0.046631
# valorização_mean       -0.105625       -0.099787   -0.072288   -0.088191
# valorização_median     -0.109351       -0.128719   -0.118207   -0.053490
# valorização_q1         -0.091311       -0.065956    0.106142   -0.206426
#
#                     governo_count  has_tweets
# datetime                -0.133366    0.225418
# VARIAÇÃO                -0.134901    0.059581
# valorização_mean        -0.023364    0.048368
# valorização_median       0.051931    0.034130
# valorização_q1          -0.284338    0.086567
#
# [5 rows x 43 columns]

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ### PETR4 Simplificado

# %%
extra = ['datetime',
 'valorização_median',
 'valorização_q1',
 'valorização_q3',
 'valorização_count',
 'bom negócio_median',
 'bom negócio_q1',
 'bom negócio_q3',
 'bom negócio_count',
 'lucro_median',
 'lucro_q1',
 'lucro_q3',
 'lucro_count',
 'neutro_median',
 'neutro_q1',
 'neutro_q3',
 'neutro_count',
 'desvalorização_median',
 'desvalorização_q1',
 'desvalorização_q3',
 'desvalorização_count',
 'mau negócio_median',
 'mau negócio_q1',
 'mau negócio_q3',
 'mau negócio_count',
 'prejuízo_median',
 'prejuízo_q1',
 'prejuízo_q3',
 'prejuízo_count',
 'governo_median',
 'governo_q1',
 'governo_q3',
 'governo_count',
]

df = petr4_final.drop(columns=extra).corr()
df
# Out:
#                      VARIAÇÃO  valorização_mean  bom negócio_mean  lucro_mean  \
# VARIAÇÃO             1.000000          0.070452          0.085335    0.037597
# valorização_mean     0.070452          1.000000          0.470584    0.396183
# bom negócio_mean     0.085335          0.470584          1.000000    0.271063
# lucro_mean           0.037597          0.396183          0.271063    1.000000
# neutro_mean          0.007883         -0.186634         -0.246599   -0.098465
# desvalorização_mean -0.097392         -0.184400         -0.380096    0.206058
# mau negócio_mean    -0.123043         -0.316671         -0.726825   -0.131493
# prejuízo_mean       -0.069841         -0.011874         -0.510241    0.028881
# governo_mean        -0.028327         -0.105625         -0.179750    0.046932
# has_tweets           0.059581          0.048368         -0.034477    0.027728
#
#                      neutro_mean  desvalorização_mean  mau negócio_mean  \
# VARIAÇÃO                0.007883            -0.097392         -0.123043
# valorização_mean       -0.186634            -0.184400         -0.316671
# bom negócio_mean       -0.246599            -0.380096         -0.726825
# lucro_mean             -0.098465             0.206058         -0.131493
# neutro_mean             1.000000             0.096552          0.223437
# desvalorização_mean     0.096552             1.000000          0.462268
# mau negócio_mean        0.223437             0.462268          1.000000
# prejuízo_mean           0.113395             0.538589          0.581087
# governo_mean           -0.043310             0.275998          0.233367
# has_tweets              0.102172            -0.014780          0.109251
#
#                      prejuízo_mean  governo_mean  has_tweets
# VARIAÇÃO                 -0.069841     -0.028327    0.059581
# valorização_mean         -0.011874     -0.105625    0.048368
# bom negócio_mean         -0.510241     -0.179750   -0.034477
# lucro_mean                0.028881      0.046932    0.027728
# neutro_mean               0.113395     -0.043310    0.102172
# desvalorização_mean       0.538589      0.275998   -0.014780
# mau negócio_mean          0.581087      0.233367    0.109251
# prejuízo_mean             1.000000      0.204923   -0.029059
# governo_mean              0.204923      1.000000   -0.105267
# has_tweets               -0.029059     -0.105267    1.000000

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ### VALE3

# %%
df = vale3_final.corr()
df.head()
# Out:
#                     datetime  VARIAÇÃO  valorização_mean  valorização_median  \
# datetime            1.000000  0.005828         -0.103363           -0.083272
# VARIAÇÃO            0.005828  1.000000          0.086110            0.089750
# valorização_mean   -0.103363  0.086110          1.000000            0.914772
# valorização_median -0.083272  0.089750          0.914772            1.000000
# valorização_q1     -0.106735  0.106481          0.928885            0.834337
#
#                     valorização_q1  valorização_q3  valorização_count  \
# datetime                 -0.106735       -0.071231           0.047401
# VARIAÇÃO                  0.106481        0.066003           0.051914
# valorização_mean          0.928885        0.803990          -0.114689
# valorização_median        0.834337        0.868361           0.062688
# valorização_q1            1.000000        0.597996          -0.212630
#
#                     bom negócio_mean  bom negócio_median  bom negócio_q1  ...  \
# datetime                    0.022191            0.045128        0.027084  ...
# VARIAÇÃO                    0.131218            0.145325        0.116166  ...
# valorização_mean            0.337729            0.324424        0.363134  ...
# valorização_median          0.304504            0.313453        0.261247  ...
# valorização_q1              0.307355            0.297005        0.377353  ...
#
#                     prejuízo_median  prejuízo_q1  prejuízo_q3  prejuízo_count  \
# datetime                   0.057316     0.037910     0.062657        0.047401
# VARIAÇÃO                  -0.097071    -0.076609    -0.087595        0.051914
# valorização_mean           0.014449     0.099296    -0.031194       -0.114689
# valorização_median        -0.010459    -0.003220     0.036407        0.062688
# valorização_q1             0.000736     0.142501    -0.080646       -0.212630
#
#                     governo_mean  governo_median  governo_q1  governo_q3  \
# datetime                0.167607        0.189651    0.094609    0.216579
# VARIAÇÃO                0.057411        0.064708    0.027023    0.076398
# valorização_mean        0.251508        0.252411    0.304190    0.149097
# valorização_median      0.220704        0.223886    0.189949    0.186174
# valorização_q1          0.192226        0.207369    0.318466    0.051784
#
#                     governo_count  has_tweets
# datetime                 0.047401   -0.106422
# VARIAÇÃO                 0.051914    0.040535
# valorização_mean        -0.114689   -0.083563
# valorização_median       0.062688   -0.027156
# valorização_q1          -0.212630   -0.079387
#
# [5 rows x 43 columns]

# %%
f = plt.figure(figsize=(19, 15))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);

# %% [markdown]
# ### VALE3 Simplificado

# %%
extra = ['datetime',
 'valorização_median',
 'valorização_q1',
 'valorização_q3',
 'valorização_count',
 'bom negócio_median',
 'bom negócio_q1',
 'bom negócio_q3',
 'bom negócio_count',
 'lucro_median',
 'lucro_q1',
 'lucro_q3',
 'lucro_count',
 'neutro_median',
 'neutro_q1',
 'neutro_q3',
 'neutro_count',
 'desvalorização_median',
 'desvalorização_q1',
 'desvalorização_q3',
 'desvalorização_count',
 'mau negócio_median',
 'mau negócio_q1',
 'mau negócio_q3',
 'mau negócio_count',
 'prejuízo_median',
 'prejuízo_q1',
 'prejuízo_q3',
 'prejuízo_count',
 'governo_median',
 'governo_q1',
 'governo_q3',
 'governo_count',
]

df = petr4_final.drop(columns=extra).corr()
df
# Out:
#                      VARIAÇÃO  valorização_mean  bom negócio_mean  lucro_mean  \
# VARIAÇÃO             1.000000          0.070452          0.085335    0.037597
# valorização_mean     0.070452          1.000000          0.470584    0.396183
# bom negócio_mean     0.085335          0.470584          1.000000    0.271063
# lucro_mean           0.037597          0.396183          0.271063    1.000000
# neutro_mean          0.007883         -0.186634         -0.246599   -0.098465
# desvalorização_mean -0.097392         -0.184400         -0.380096    0.206058
# mau negócio_mean    -0.123043         -0.316671         -0.726825   -0.131493
# prejuízo_mean       -0.069841         -0.011874         -0.510241    0.028881
# governo_mean        -0.028327         -0.105625         -0.179750    0.046932
# has_tweets           0.059581          0.048368         -0.034477    0.027728
#
#                      neutro_mean  desvalorização_mean  mau negócio_mean  \
# VARIAÇÃO                0.007883            -0.097392         -0.123043
# valorização_mean       -0.186634            -0.184400         -0.316671
# bom negócio_mean       -0.246599            -0.380096         -0.726825
# lucro_mean             -0.098465             0.206058         -0.131493
# neutro_mean             1.000000             0.096552          0.223437
# desvalorização_mean     0.096552             1.000000          0.462268
# mau negócio_mean        0.223437             0.462268          1.000000
# prejuízo_mean           0.113395             0.538589          0.581087
# governo_mean           -0.043310             0.275998          0.233367
# has_tweets              0.102172            -0.014780          0.109251
#
#                      prejuízo_mean  governo_mean  has_tweets
# VARIAÇÃO                 -0.069841     -0.028327    0.059581
# valorização_mean         -0.011874     -0.105625    0.048368
# bom negócio_mean         -0.510241     -0.179750   -0.034477
# lucro_mean                0.028881      0.046932    0.027728
# neutro_mean               0.113395     -0.043310    0.102172
# desvalorização_mean       0.538589      0.275998   -0.014780
# mau negócio_mean          0.581087      0.233367    0.109251
# prejuízo_mean             1.000000      0.204923   -0.029059
# governo_mean              0.204923      1.000000   -0.105267
# has_tweets               -0.029059     -0.105267    1.000000

# %%
f = plt.figure(figsize=(10, 10))
plt.matshow(df.corr(), fignum=f.number)
plt.xticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df.select_dtypes(['number']).shape[1]), df.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('Correlation Matrix', fontsize=16);
